# %%
import pandas as pd

# %%
df = pd.read_json('../data/results.json',lines=True)
df = (pd.DataFrame(df['specs'].values.tolist()).join(df.drop('specs', axis=1)))
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#            Manufacturer  Made_In                  FX   Type Jacks_mounted_on  \
# 0      Electro-Harmonix      USA               Delay  Pedal            Sides
# 1            Danelectro    China                Fuzz  Pedal              Top
# 2          Walrus Audio      USA           Overdrive  Pedal            Sides
# 3                Ibanez    Japan                Fuzz  Pedal            Sides
# 4                  BOSS   Taiwan  Acoustic Simulator  Pedal            Sides
# ..                  ...      ...                 ...    ...              ...
# 400           Tone City    China          Distortion  Pedal            Sides
# 401               Aclam    Spain           Overdrive  Pedal              Top
# 402                Wish    China           Overdrive  Pedal              Top
# 403  KMA Audio Machines  Germany          Distortion  Pedal            Sides
# 404              Keeley      USA       Delay, Reverb  Pedal              Top
#
# ...
